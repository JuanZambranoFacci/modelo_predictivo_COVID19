# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import seaborn as sns
from pylab import rcParams
import matplotlib.pyplot as ply
from matplotlib import rc
from sklearn.model_selection import train_test_split
from pandas.plotting import register_matplotlib_converters

# %%
# Carga del dataset Casos por COVID-19
df1 = pd.read_csv("Covid-19EC_Dataset.csv")

# %%
# Conversión del campo fecha
df1["fecha"] = pd.to_datetime(df1["fecha"], errors = 'coerce')
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8610 entries, 0 to 8609
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fecha                 8610 non-null   datetime64[ns]
#  1   día                   8610 non-null   int64
#  2   mes                   8610 non-null   int64
#  3   año                   8610 non-null   int64
#  4   casosConfirmados      8610 non-null   int64
#  5   casosDiarios          8610 non-null   int64
#  6   fallecimientos        8610 non-null   int64
#  7   nuevosFallecimientos  8610 non-null   int64
#  8   provincia             8610 non-null   object
#  9   región                8610 non-null   object
# dtypes: datetime64[ns](1), int64(7), object(2)
# memory usage: 672.8+ KB

# %%
df1
# Out:
#           fecha  día  mes   año  ...  fallecimientos  nuevosFallecimientos         provincia    región
# 0    2020-03-13   13    3  2020  ...               0                     0             Azuay    Sierra
# 1    2020-03-14   14    3  2020  ...               0                     0             Azuay    Sierra
# 2    2020-03-15   15    3  2020  ...               0                     0             Azuay    Sierra
# 3    2020-03-16   16    3  2020  ...               0                     0             Azuay    Sierra
# 4    2020-03-17   17    3  2020  ...               0                     0             Azuay    Sierra
# ...         ...  ...  ...   ...  ...             ...                   ...               ...       ...
# 8605 2021-03-09    9    3  2021  ...              63                     0  Zamora Chinchipe  Amazonía
# 8606 2021-03-10   10    3  2021  ...              64                     1  Zamora Chinchipe  Amazonía
# 8607 2021-03-11   11    3  2021  ...              65                     1  Zamora Chinchipe  Amazonía
# 8608 2021-03-12   12    3  2021  ...              66                     1  Zamora Chinchipe  Amazonía
# 8609 2021-03-13   13    3  2021  ...              66                     0  Zamora Chinchipe  Amazonía
#
# [8610 rows x 10 columns]

# %%
# Configuración del campo fecha como identificador
df1.set_index("fecha", inplace = True)

# %%
df1
# Out:
#             día  mes   año  casosConfirmados  ...  fallecimientos  nuevosFallecimientos         provincia    región
# fecha                                         ...
# 2020-03-13   13    3  2020                 0  ...               0                     0             Azuay    Sierra
# 2020-03-14   14    3  2020                 1  ...               0                     0             Azuay    Sierra
# 2020-03-15   15    3  2020                 1  ...               0                     0             Azuay    Sierra
# 2020-03-16   16    3  2020                 1  ...               0                     0             Azuay    Sierra
# 2020-03-17   17    3  2020                 5  ...               0                     0             Azuay    Sierra
# ...         ...  ...   ...               ...  ...             ...                   ...               ...       ...
# 2021-03-09    9    3  2021              1971  ...              63                     0  Zamora Chinchipe  Amazonía
# 2021-03-10   10    3  2021              1984  ...              64                     1  Zamora Chinchipe  Amazonía
# 2021-03-11   11    3  2021              1985  ...              65                     1  Zamora Chinchipe  Amazonía
# 2021-03-12   12    3  2021              2005  ...              66                     1  Zamora Chinchipe  Amazonía
# 2021-03-13   13    3  2021              2012  ...              66                     0  Zamora Chinchipe  Amazonía
#
# [8610 rows x 9 columns]

# %%
sns.lineplot(x=df1.index, y='casosConfirmados', data=df1);
